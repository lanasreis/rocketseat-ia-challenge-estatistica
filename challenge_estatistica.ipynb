# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dicionário de faturamento
dict_faturamento = {
    'data_ref': [
        '2023-01-01', 
        '2020-02-01', 
        '2021-03-01', 
        '2022-04-01', 
        '2023-05-01',
        '2023-06-01', 
        '2020-07-01', 
        '2021-08-01', 
        '2022-09-01', 
        '2023-10-01',
        '2022-11-01', 
        '2023-12-01',
        ],
    'valor': [
        400000, 
        890000, 
        760000, 
        430000, 
        920000,
        340000, 
        800000, 
        500000, 
        200000, 
        900000,
        570000, 
        995000,
        ]
}

# %%
df_faturamento = pd.DataFrame.from_dict(dict_faturamento)

# %%
df_faturamento['data_ref'] = pd.to_datetime(df_faturamento['data_ref'])
df_faturamento['mes_ano'] = df_faturamento['data_ref'].dt.strftime('%m-%Y')

# %%
df_faturamento
# Out:
#      data_ref   valor  mes_ano
# 0  2023-01-01  400000  01-2023
# 1  2020-02-01  890000  02-2020
# 2  2021-03-01  760000  03-2021
# 3  2022-04-01  430000  04-2022
# 4  2023-05-01  920000  05-2023
# 5  2023-06-01  340000  06-2023
# 6  2020-07-01  800000  07-2020
# 7  2021-08-01  500000  08-2021
# 8  2022-09-01  200000  09-2022
# 9  2023-10-01  900000  10-2023
# 10 2022-11-01  570000  11-2022
# 11 2023-12-01  995000  12-2023

# %%
# Media de vendas

df_faturamento.valor.mean()
# Out:
# np.float64(642083.3333333334)

# %%
# Grafico de barras vertical

df_faturamento.sort_values('data_ref').plot.bar(x='mes_ano', y='valor')
# Out:
# <Axes: xlabel='mes_ano'>

# %%
# Grafico de barras vertical

df_faturamento.sort_values('data_ref').plot.line(x='mes_ano', y='valor')
# Out:
# <Axes: xlabel='mes_ano'>
